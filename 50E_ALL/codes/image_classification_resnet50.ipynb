# %% [markdown]
# # **Fine-tuning for Image Classification with 🤗 Transformers**
#
# This notebook shows how to fine-tune any pretrained Vision model for Image Classification on a custom dataset. The idea is to add a randomly initialized classification head on top of a pre-trained encoder, and fine-tune the model altogether on a labeled dataset.
#
# ## ImageFolder
#
# This notebook leverages the [ImageFolder](https://huggingface.co/docs/datasets/v2.0.0/en/image_process#imagefolder)
#
# ## Any model
#
# This notebook is built to run on any image classification dataset with any vision model checkpoint from the [Model Hub](https://huggingface.co/) as long as that model has a version with a Image Classification head, any model supported by [AutoModelForImageClassification](https://huggingface.co/docs/transformers/model_doc/auto#transformers.AutoModelForImageClassification).
#
# ## Data augmentation
#
# This notebook leverages Torchvision's [transforms](https://pytorch.org/vision/stable/transforms.html) for applying data augmentation.

# %% [markdown]
# ### Pre-Setup

# %%
# Setting up the cache
import os
caches_dir = ["F:/.cache/", "D:/cache/"]

# Will set the cache in the first caches dir found in the storage
for cache in caches_dir:
    if os.path.exists(cache):
        os.environ['HF_HOME'] = cache
        print(f"Cache path set on {cache}")
        break
    else:
        print(f"Path does not  exist {cache}")
# Out:
# Cache path set on F:/.cache/

# %% [markdown]
# Before we start, let's install the `datasets`, `transformers` and `accelerate` libraries.

# %%
# !pip install transformers==4.39.3
# !pip install -q datasets accelerate
# !pip install -q evaluate
# !pip install pandas
# !pip install matplotlib
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# !pip install wandb
# Out:
# Requirement already satisfied: transformers==4.39.3 in c:\users\dhan\anaconda3\lib\site-packages (4.39.3)
# Requirement already satisfied: filelock in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (2024.4.16)
# Requirement already satisfied: requests in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dhan\anaconda3\lib\site-packages (from transformers==4.39.3) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dhan\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dhan\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.3) (4.11.0)
# Requirement already satisfied: colorama in c:\users\dhan\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.39.3) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhan\anaconda3\lib\site-packages (from requests->transformers==4.39.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhan\anaconda3\lib\site-packages (from requests->transformers==4.39.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhan\anaconda3\lib\site-packages (from requests->transformers==4.39.3) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhan\anaconda3\lib\site-packages (from requests->transformers==4.39.3) (2024.2.2)
# Requirement already satisfied: pandas in c:\users\dhan\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\dhan\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhan\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhan\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dhan\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dhan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\dhan\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dhan\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dhan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\dhan\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: torchvision in c:\users\dhan\anaconda3\lib\site-packages (0.17.2)
# Requirement already satisfied: filelock in c:\users\dhan\anaconda3\lib\site-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dhan\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\dhan\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\dhan\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dhan\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\dhan\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in c:\users\dhan\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\dhan\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dhan\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dhan\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: wandb in c:\users\dhan\anaconda3\lib\site-packages (0.16.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (3.1.37)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (2.0.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (68.2.2)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\dhan\anaconda3\lib\site-packages (from wandb) (3.20.3)
# Requirement already satisfied: colorama in c:\users\dhan\anaconda3\lib\site-packages (from Click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\dhan\anaconda3\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dhan\anaconda3\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhan\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhan\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhan\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhan\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\dhan\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (4.0.0)

# %%
# !conda install anaconda::ipywidgets
# Out:
# ^C

# %% [markdown]
# If you're opening this notebook locally, make sure your environment has an install from the last version of those libraries.
#
# To be able to share your model with the community and generate results like the one shown in the picture below via the inference API, there are a few more steps to follow.
#
# First you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!) then execute the following cell and input your token:

# %% [markdown]
# ### Huggingface Login & wandb

# %%
#from huggingface_hub import notebook_login
#notebook_login()

# %%
import wandb
wandb.login()

# %% [markdown]
# Then you need to install Git-LFS to upload your model checkpoints:

# %%
# %%capture
# !sudo apt -qq install git-lfs
# !git config --global credential.helper store

# %% [markdown]
# ### Loading the dataset

# %%
model_checkpoint = "microsoft/resnet-50" # pre-trained model from which to fine-tune

# %%
import os

path = r"TREES_2.tar"
if not os.path.exists(path):
    print(f"Path does not  exist {path}")

# %%
from datasets import load_dataset

# load a custom dataset from local/remote files or folders using the ImageFolder feature
dataset = load_dataset("imagefolder", data_files=path)

# %% [markdown]
# The `dataset` object itself is a [`DatasetDict`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasetdict), which contains one key per split (in this case, only "train" for a training split).

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 959
#     })
# })

# %%
dataset["train"].features
# Out:
# {'image': Image(mode=None, decode=True, id=None),
#  'label': ClassLabel(names=['Iinstia bijuga', 'Mangifera indica', 'Pterocarpus indicus', 'Roystonea regia', 'Tabebuia'], id=None)}

# %%
example = dataset['train'][310]['image']
example.resize(size=(224, 224)).save("example_tree_resized.jpg", quality=95)
example.save("example_tree.jpg", quality=95)
example.resize(size=(224, 224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Let's print the corresponding label:

# %%
labels = dataset["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

label2id
# Out:
# {'Iinstia bijuga': 0,
#  'Mangifera indica': 1,
#  'Pterocarpus indicus': 2,
#  'Roystonea regia': 3,
#  'Tabebuia': 4}

# %% [markdown]
# ### Preprocessing the data

# %%
from transformers import AutoImageProcessor

image_processor  = AutoImageProcessor.from_pretrained(model_checkpoint)
image_processor
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# ConvNextImageProcessor {
#   "_valid_processor_keys": [
#     "images",
#     "do_resize",
#     "size",
#     "crop_pct",
#     "resample",
#     "do_rescale",
#     "rescale_factor",
#     "do_normalize",
#     "image_mean",
#     "image_std",
#     "return_tensors",
#     "data_format",
#     "input_data_format"
#   ],
#   "crop_pct": 0.875,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_processor_type": "ConvNextImageProcessor",
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "shortest_edge": 224
#   }
# }

# %%
import torch
import random
from torchvision.transforms.v2 import (
    CenterCrop,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    Resize,
    RandAugment,
    RandomRotation,
    ToImage,
    ToDtype,
)


normalize = Normalize(mean=image_processor.image_mean, std=image_processor.image_std)
if "height" in image_processor.size:
    size = (image_processor.size["height"], image_processor.size["width"])
    crop_size = size
    max_size = None
elif "shortest_edge" in image_processor.size:
    size = image_processor.size["shortest_edge"]
    crop_size = (size, size)
    max_size = image_processor.size.get("longest_edge")

train_transforms = Compose(
        [
            ToImage(),
            RandomHorizontalFlip(p=0.5),
            RandomResizedCrop(crop_size, scale=(0.5, 1.0)),
            RandAugment(num_ops=2),
            ToDtype(torch.float32, scale=True),
            normalize,
        ]
    )

val_transforms = Compose(
        [
            ToImage(),
            Resize(size),
            CenterCrop(crop_size),
            ToDtype(torch.float32, scale=True),
            normalize,
        ]
    )

def preprocess_train(example_batch):
    """Apply train_transforms across a batch."""

    example_batch["pixel_values"] = [
        train_transforms(image.convert("RGB")) for image in example_batch["image"]
    ]
    return example_batch

def preprocess_val(example_batch):
    """Apply val_transforms across a batch."""
    example_batch["pixel_values"] = [val_transforms(image.convert("RGB")) for image in example_batch["image"]]
    return example_batch

# %% [markdown]
# Next, we can preprocess our dataset by applying these functions. We will use the `set_transform` functionality, which allows to apply the functions above on-the-fly (meaning that they will only be applied when the images are loaded in RAM).

# %%
# split up training into training + validation
splits = dataset["train"].train_test_split(test_size=0.2, shuffle=True)
test_valid = splits['test'].train_test_split(test_size=0.5)

train_ds = splits['train']
val_ds = test_valid['train']
test_ds = test_valid['test']

# %%
train_ds.set_transform(preprocess_train)
val_ds.set_transform(preprocess_val)
test_ds.set_transform(preprocess_val)

# %% [markdown]
# ### Logging Visualization WANDB

# %%
# set the wandb project where this run will be logged
# os.environ["WANDB_PROJECT"]="fatih-tree-bark"

# save your trained model checkpoint to wandb
# os.environ["WANDB_LOG_MODEL"]="true"

# turn off watch to log faster
# os.environ["WANDB_WATCH"]="false"

# turn off wandb
os.environ["WANDB_DISABLED"] = "true"

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now that our data is ready, we can download the pretrained model and fine-tune it. For classification we use the `AutoModelForImageClassification` class. Calling the `from_pretrained` method on it will download and cache the weights for us. As the label ids and the number of labels are dataset dependent, we pass `label2id`, and `id2label` alongside the `model_checkpoint` here. This will make sure a custom classification head will be created (with a custom number of output neurons).

# %%
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

model = AutoModelForImageClassification.from_pretrained(
    model_checkpoint,
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes = True, # provide this in case you're planning to fine-tune an already fine-tuned checkpoint
)
# Out:
# Some weights of ResNetForImageClassification were not initialized from the model checkpoint at microsoft/resnet-50 and are newly initialized because the shapes did not match:
# - classifier.1.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([5]) in the model instantiated
# - classifier.1.weight: found shape torch.Size([1000, 2048]) in the checkpoint and torch.Size([5, 2048]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The warning is telling us we are throwing away some weights (the weights and bias of the `classifier` layer) and randomly initializing some other (the weights and bias of a new `classifier` layer). This is expected in this case, because we are adding a new head for which we don't have pretrained weights, so the library warns us we should fine-tune this model before using it for inference, which is exactly what we are going to do.

# %% [markdown]
# To instantiate a `Trainer`, we will need to define the training configuration and the evaluation metric. The most important is the [`TrainingArguments`](https://huggingface.co/transformers/main_classes/trainer.html#transformers.TrainingArguments), which is a class that contains all the attributes to customize the training. It requires one folder name, which will be used to save the checkpoints of the model.
#
# Most of the training arguments are pretty self-explanatory, but one that is quite important here is `remove_unused_columns=False`. This one will drop any features not used by the model's call function. By default it's `True` because usually it's ideal to drop unused feature columns, making it easier to unpack inputs into the model's call function. But, in our case, we need the unused features ('image' in particular) in order to create 'pixel_values'.

# %%
model_name = model_checkpoint.split("/")[-1]
batch_size = 8

args = TrainingArguments(
    f"{model_name}-finetuned-FBark",
    remove_unused_columns=False,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=4,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=50,
    warmup_ratio=0.1,
    weight_decay=1e-4,
    logging_steps=50,
    logging_strategy="epoch",
    logging_dir='./logs',
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
   # push_to_hub=True,
   # report_to="wandb"
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %% [markdown]
# Here we set the evaluation to be done at the end of each epoch, tweak the learning rate, use the `batch_size` defined at the top of the notebook and customize the number of epochs for training, as well as the weight decay. Since the best model might not be the one at the end of training, we ask the `Trainer` to load the best model it saved (according to `metric_name`) at the end of training.

# %% [markdown]
# Next, we need to define a function for how to compute the metrics from the predictions, which will just use the `metric` we loaded earlier. The only preprocessing we have to do is to take the argmax of our predicted logits:

# %%
import evaluate
import numpy as np
# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.

def compute_metrics(eval_pred):
    metric1 = evaluate.load("precision")
    metric2 = evaluate.load("recall")
    metric3 = evaluate.load("f1")
    metric4 = evaluate.load("accuracy")

    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=1)

    precision = metric1.compute(predictions=predictions, references=labels, average="macro")["precision"]
    recall = metric2.compute(predictions=predictions, references=labels, average="macro")["recall"]
    f1 = metric3.compute(predictions=predictions, references=labels, average="macro")["f1"]
    accuracy = metric4.compute(predictions=predictions, references=labels)["accuracy"]

    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

# %%
from transformers import TrainerCallback
from copy import deepcopy

class CustomCallback(TrainerCallback):
    # This is for getting the accuracy logs
    def __init__(self, trainer) -> None:
        super().__init__()
        self._trainer = trainer

    def on_epoch_end(self, args, state, control, **kwargs):
        if control.should_evaluate:
            control_copy = deepcopy(control)
            self._trainer.evaluate(eval_dataset=self._trainer.train_dataset, metric_key_prefix="train")
            return control_copy

# %% [markdown]
# We also define a `collate_fn`, which will be used to batch examples together.
# Each batch consists of 2 keys, namely `pixel_values` and `labels`.

# %%
import torch

def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %% [markdown]
# Then we just need to pass all of this along with our datasets to the `Trainer`:

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    tokenizer=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)
trainer.add_callback(CustomCallback(trainer))

# %% [markdown]
# You might wonder why we pass along the `image_processor` as a tokenizer when we already preprocessed our data. This is only to make sure the image processor configuration file (stored as JSON) will also be uploaded to the repo on the hub.

# %% [markdown]
# Now we can finetune our model by calling the `train` method:

# %%
train_results = trainer.train(resume_from_checkpoint=True)
# rest is optional but nice to have
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
#     <div>
#
#       <progress value='1200' max='1200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1200/1200 : < :, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ***** train metrics *****
#   epoch                    =        50.0
#   total_flos               = 758646644GF
#   train_loss               =         0.0
#   train_runtime            =  0:00:00.18
#   train_samples_per_second =  205003.853
#   train_steps_per_second   =    6414.723

# %% [markdown]
# We can check with the `evaluate` method that our `Trainer` did reload the best model properly (if it was not the last one):

# %%
metrics = trainer.evaluate(eval_dataset=test_ds) # Using the test dataset to evaluate the model
# some nice to haves:
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 01:04]
#     </div>
# ***** eval metrics *****
#   epoch                   =       50.0
#   eval_accuracy           =     0.9479
#   eval_f1                 =     0.9526
#   eval_loss               =     0.1097
#   eval_precision          =     0.9581
#   eval_recall             =     0.9519
#   eval_runtime            = 0:01:37.97
#   eval_samples_per_second =       0.98
#   eval_steps_per_second   =      0.122

# %%
#trainer.push_to_hub()

# %%
wandb.finish()

# %% [markdown]
# ### Visualization

# %%
import pandas as pd
history = trainer.state.log_history
history
# Out:
# [{'epoch': 1.0,
#   'step': 24,
#   'train_accuracy': 0.17079530638852672,
#   'train_f1': 0.05835189309576837,
#   'train_loss': 18.04694938659668,
#   'train_precision': 0.03415906127770534,
#   'train_recall': 0.2,
#   'train_runtime': 203.9961,
#   'train_samples_per_second': 3.76,
#   'train_steps_per_second': 0.471},
#  {'epoch': 1.0,
#   'grad_norm': 10.124311447143555,
#   'learning_rate': 1e-05,
#   'loss': 18.0536,
#   'step': 24},
#  {'epoch': 1.0,
#   'eval_accuracy': 0.16666666666666666,
#   'eval_f1': 0.05714285714285714,
#   'eval_loss': 16.590553283691406,
#   'eval_precision': 0.03333333333333333,
#   'eval_recall': 0.2,
#   'eval_runtime': 32.2503,
#   'eval_samples_per_second': 2.977,
#   'eval_steps_per_second': 0.372,
#   'step': 24},
#  {'epoch': 2.0,
#   'step': 48,
#   'train_accuracy': 0.17079530638852672,
#   'train_f1': 0.05835189309576837,
#   'train_loss': 17.32846450805664,
#   'train_precision': 0.03415906127770534,
#   'train_recall': 0.2,
#   'train_runtime': 202.9979,
#   'train_samples_per_second': 3.778,
#   'train_steps_per_second': 0.473},
#  {'epoch': 2.0,
#   'grad_norm': 10.14943790435791,
#   'learning_rate': 2e-05,
#   'loss': 17.8543,
#   'step': 48},
#  {'epoch': 2.0,
#   'eval_accuracy': 0.16666666666666666,
#   'eval_f1': 0.05714285714285714,
#   'eval_loss': 15.916254997253418,
#   'eval_precision': 0.03333333333333333,
#   'eval_recall': 0.2,
#   'eval_runtime': 32.5421,
#   'eval_samples_per_second': 2.95,
#   'eval_steps_per_second': 0.369,
#   'step': 48},
#  {'epoch': 3.0,
#   'step': 72,
#   'train_accuracy': 0.17470664928292046,
#   'train_f1': 0.06609465584484031,
#   'train_loss': 17.039255142211914,
#   'train_precision': 0.2342931937172775,
#   'train_recall': 0.20384615384615384,
#   'train_runtime': 202.9207,
#   'train_samples_per_second': 3.78,
#   'train_steps_per_second': 0.473},
#  {'epoch': 3.0,
#   'grad_norm': 9.922247886657715,
#   'learning_rate': 3e-05,
#   'loss': 17.4405,
#   'step': 72},
#  {'epoch': 3.0,
#   'eval_accuracy': 0.16666666666666666,
#   'eval_f1': 0.05765765765765766,
#   'eval_loss': 14.995741844177246,
#   'eval_precision': 0.03368421052631579,
#   'eval_recall': 0.2,
#   'eval_runtime': 32.4214,
#   'eval_samples_per_second': 2.961,
#   'eval_steps_per_second': 0.37,
#   'step': 72},
#  {'epoch': 4.0,
#   'step': 96,
#   'train_accuracy': 0.17861799217731422,
#   'train_f1': 0.0735592094336489,
#   'train_loss': 17.1055908203125,
#   'train_precision': 0.23442838370565044,
#   'train_recall': 0.2076923076923077,
#   'train_runtime': 205.2629,
#   'train_samples_per_second': 3.737,
#   'train_steps_per_second': 0.468},
#  {'epoch': 4.0,
#   'grad_norm': 12.05506706237793,
#   'learning_rate': 4e-05,
#   'loss': 16.7123,
#   'step': 96},
#  {'epoch': 4.0,
#   'eval_accuracy': 0.17708333333333334,
#   'eval_f1': 0.07818181818181817,
#   'eval_loss': 14.85153579711914,
#   'eval_precision': 0.13404255319148936,
#   'eval_recall': 0.2111111111111111,
#   'eval_runtime': 32.8355,
#   'eval_samples_per_second': 2.924,
#   'eval_steps_per_second': 0.365,
#   'step': 96},
#  {'epoch': 5.0,
#   'step': 120,
#   'train_accuracy': 0.23728813559322035,
#   'train_f1': 0.15487266112266113,
#   'train_loss': 14.29334831237793,
#   'train_precision': 0.19192063286214497,
#   'train_recall': 0.2653846153846154,
#   'train_runtime': 199.5554,
#   'train_samples_per_second': 3.844,
#   'train_steps_per_second': 0.481},
#  {'epoch': 5.0,
#   'grad_norm': 12.255631446838379,
#   'learning_rate': 5e-05,
#   'loss': 15.9181,
#   'step': 120},
#  {'epoch': 5.0,
#   'eval_accuracy': 0.3229166666666667,
#   'eval_f1': 0.2182515757741847,
#   'eval_loss': 10.63965129852295,
#   'eval_precision': 0.17427039904705183,
#   'eval_recall': 0.3666666666666667,
#   'eval_runtime': 31.5782,
#   'eval_samples_per_second': 3.04,
#   'eval_steps_per_second': 0.38,
#   'step': 120},
#  {'epoch': 6.0,
#   'step': 144,
#   'train_accuracy': 0.21121251629726207,
#   'train_f1': 0.12113292710449108,
#   'train_loss': 14.31035041809082,
#   'train_precision': 0.15156095787231832,
#   'train_recall': 0.23974358974358972,
#   'train_runtime': 202.3,
#   'train_samples_per_second': 3.791,
#   'train_steps_per_second': 0.475},
#  {'epoch': 6.0,
#   'grad_norm': 15.252593994140625,
#   'learning_rate': 6e-05,
#   'loss': 14.9568,
#   'step': 144},
#  {'epoch': 6.0,
#   'eval_accuracy': 0.28125,
#   'eval_f1': 0.1853546910755149,
#   'eval_loss': 10.616622924804688,
#   'eval_precision': 0.15210526315789474,
#   'eval_recall': 0.32222222222222224,
#   'eval_runtime': 32.1813,
#   'eval_samples_per_second': 2.983,
#   'eval_steps_per_second': 0.373,
#   'step': 144},
#  {'epoch': 7.0,
#   'step': 168,
#   'train_accuracy': 0.22033898305084745,
#   'train_f1': 0.13315297835185852,
#   'train_loss': 13.796942710876465,
#   'train_precision': 0.165819209039548,
#   'train_recall': 0.24871794871794872,
#   'train_runtime': 213.7712,
#   'train_samples_per_second': 3.588,
#   'train_steps_per_second': 0.449},
#  {'epoch': 7.0,
#   'grad_norm': 17.817716598510742,
#   'learning_rate': 7e-05,
#   'loss': 13.9814,
#   'step': 168},
#  {'epoch': 7.0,
#   'eval_accuracy': 0.2916666666666667,
#   'eval_f1': 0.1911111111111111,
#   'eval_loss': 10.169219017028809,
#   'eval_precision': 0.15233415233415232,
#   'eval_recall': 0.3333333333333333,
#   'eval_runtime': 34.3388,
#   'eval_samples_per_second': 2.796,
#   'eval_steps_per_second': 0.349,
#   'step': 168},
#  {'epoch': 8.0,
#   'step': 192,
#   'train_accuracy': 0.23859191655801826,
#   'train_f1': 0.1432839461008475,
#   'train_loss': 11.88978099822998,
#   'train_precision': 0.1291965811965812,
#   'train_recall': 0.26666666666666666,
#   'train_runtime': 213.2035,
#   'train_samples_per_second': 3.598,
#   'train_steps_per_second': 0.45},
#  {'epoch': 8.0,
#   'grad_norm': 24.964458465576172,
#   'learning_rate': 8e-05,
#   'loss': 12.8457,
#   'step': 192},
#  {'epoch': 8.0,
#   'eval_accuracy': 0.3229166666666667,
#   'eval_f1': 0.19632443028669444,
#   'eval_loss': 8.517545700073242,
#   'eval_precision': 0.13817330210772832,
#   'eval_recall': 0.3666666666666667,
#   'eval_runtime': 33.5577,
#   'eval_samples_per_second': 2.861,
#   'eval_steps_per_second': 0.358,
#   'step': 192},
#  {'epoch': 9.0,
#   'step': 216,
#   'train_accuracy': 0.23076923076923078,
#   'train_f1': 0.12682000911765925,
#   'train_loss': 10.316431045532227,
#   'train_precision': 0.11095681221665474,
#   'train_recall': 0.2502732240437159,
#   'train_runtime': 210.292,
#   'train_samples_per_second': 3.647,
#   'train_steps_per_second': 0.457},
#  {'epoch': 9.0,
#   'grad_norm': 26.0004940032959,
#   'learning_rate': 9e-05,
#   'loss': 11.7118,
#   'step': 216},
#  {'epoch': 9.0,
#   'eval_accuracy': 0.25,
#   'eval_f1': 0.1555764411027569,
#   'eval_loss': 8.164079666137695,
#   'eval_precision': 0.2989106753812636,
#   'eval_recall': 0.2777777777777778,
#   'eval_runtime': 33.1894,
#   'eval_samples_per_second': 2.892,
#   'eval_steps_per_second': 0.362,
#   'step': 216},
#  {'epoch': 10.0,
#   'step': 240,
#   'train_accuracy': 0.2516297262059974,
#   'train_f1': 0.14264487137332268,
#   'train_loss': 9.594059944152832,
#   'train_precision': 0.11829280516408396,
#   'train_recall': 0.26775956284153,
#   'train_runtime': 207.0386,
#   'train_samples_per_second': 3.705,
#   'train_steps_per_second': 0.464},
#  {'epoch': 10.0,
#   'grad_norm': 24.830373764038086,
#   'learning_rate': 0.0001,
#   'loss': 10.5923,
#   'step': 240},
#  {'epoch': 10.0,
#   'eval_accuracy': 0.2604166666666667,
#   'eval_f1': 0.1475058275058275,
#   'eval_loss': 7.646785259246826,
#   'eval_precision': 0.10455407969639467,
#   'eval_recall': 0.2857142857142857,
#   'eval_runtime': 31.8129,
#   'eval_samples_per_second': 3.018,
#   'eval_steps_per_second': 0.377,
#   'step': 240},
#  {'epoch': 11.0,
#   'step': 264,
#   'train_accuracy': 0.27640156453715775,
#   'train_f1': 0.18709378085924963,
#   'train_loss': 8.720396041870117,
#   'train_precision': 0.3117990544223779,
#   'train_recall': 0.29173375603109053,
#   'train_runtime': 200.2724,
#   'train_samples_per_second': 3.83,
#   'train_steps_per_second': 0.479},
#  {'epoch': 11.0,
#   'grad_norm': 25.278486251831055,
#   'learning_rate': 9.888888888888889e-05,
#   'loss': 9.4909,
#   'step': 264},
#  {'epoch': 11.0,
#   'eval_accuracy': 0.28125,
#   'eval_f1': 0.19058823529411764,
#   'eval_loss': 7.4518561363220215,
#   'eval_precision': 0.31,
#   'eval_recall': 0.30793650793650795,
#   'eval_runtime': 31.842,
#   'eval_samples_per_second': 3.015,
#   'eval_steps_per_second': 0.377,
#   'step': 264},
#  {'epoch': 12.0,
#   'step': 288,
#   'train_accuracy': 0.29465449804432853,
#   'train_f1': 0.21576826553068815,
#   'train_loss': 8.02353286743164,
#   'train_precision': 0.2815030174882164,
#   'train_recall': 0.3104629963611023,
#   'train_runtime': 205.0265,
#   'train_samples_per_second': 3.741,
#   'train_steps_per_second': 0.468},
#  {'epoch': 12.0,
#   'grad_norm': 21.497766494750977,
#   'learning_rate': 9.777777777777778e-05,
#   'loss': 8.4454,
#   'step': 288},
#  {'epoch': 12.0,
#   'eval_accuracy': 0.3229166666666667,
#   'eval_f1': 0.24850477740503316,
#   'eval_loss': 7.306539058685303,
#   'eval_precision': 0.3191256830601093,
#   'eval_recall': 0.35079365079365077,
#   'eval_runtime': 32.6536,
#   'eval_samples_per_second': 2.94,
#   'eval_steps_per_second': 0.367,
#   'step': 288},
#  {'epoch': 13.0,
#   'step': 312,
#   'train_accuracy': 0.43546284224250326,
#   'train_f1': 0.3915571010652978,
#   'train_loss': 6.564652919769287,
#   'train_precision': 0.4793136205183114,
#   'train_recall': 0.4433491983408434,
#   'train_runtime': 201.0843,
#   'train_samples_per_second': 3.814,
#   'train_steps_per_second': 0.477},
#  {'epoch': 13.0,
#   'grad_norm': 34.2852783203125,
#   'learning_rate': 9.666666666666667e-05,
#   'loss': 7.6662,
#   'step': 312},
#  {'epoch': 13.0,
#   'eval_accuracy': 0.46875,
#   'eval_f1': 0.4287591706539075,
#   'eval_loss': 6.737512111663818,
#   'eval_precision': 0.47393124522536284,
#   'eval_recall': 0.5047619047619047,
#   'eval_runtime': 32.6226,
#   'eval_samples_per_second': 2.943,
#   'eval_steps_per_second': 0.368,
#   'step': 312},
#  {'epoch': 14.0,
#   'step': 336,
#   'train_accuracy': 0.3350717079530639,
#   'train_f1': 0.25173880309656954,
#   'train_loss': 6.4295854568481445,
#   'train_precision': 0.3217560405291883,
#   'train_recall': 0.34518948195805244,
#   'train_runtime': 200.3623,
#   'train_samples_per_second': 3.828,
#   'train_steps_per_second': 0.479},
#  {'epoch': 14.0,
#   'grad_norm': 33.01333999633789,
#   'learning_rate': 9.555555555555557e-05,
#   'loss': 6.5476,
#   'step': 336},
#  {'epoch': 14.0,
#   'eval_accuracy': 0.3020833333333333,
#   'eval_f1': 0.19007979665904953,
#   'eval_loss': 6.520298480987549,
#   'eval_precision': 0.3192982456140351,
#   'eval_recall': 0.3253968253968254,
#   'eval_runtime': 31.6015,
#   'eval_samples_per_second': 3.038,
#   'eval_steps_per_second': 0.38,
#   'step': 336},
#  {'epoch': 15.0,
#   'step': 360,
#   'train_accuracy': 0.3324641460234681,
#   'train_f1': 0.2396710562655914,
#   'train_loss': 6.037327289581299,
#   'train_precision': 0.5197594554480782,
#   'train_recall': 0.34146382880841497,
#   'train_runtime': 203.0467,
#   'train_samples_per_second': 3.777,
#   'train_steps_per_second': 0.473},
#  {'epoch': 15.0,
#   'grad_norm': 33.36974334716797,
#   'learning_rate': 9.444444444444444e-05,
#   'loss': 5.8062,
#   'step': 360},
#  {'epoch': 15.0,
#   'eval_accuracy': 0.3125,
#   'eval_f1': 0.23909980430528374,
#   'eval_loss': 5.776089191436768,
#   'eval_precision': 0.5132832080200501,
#   'eval_recall': 0.3396825396825397,
#   'eval_runtime': 40.2171,
#   'eval_samples_per_second': 2.387,
#   'eval_steps_per_second': 0.298,
#   'step': 360},
#  {'epoch': 16.0,
#   'step': 384,
#   'train_accuracy': 0.3272490221642764,
#   'train_f1': 0.2568949991257213,
#   'train_loss': 4.929172515869141,
#   'train_precision': 0.4561755573669902,
#   'train_recall': 0.34101822317830033,
#   'train_runtime': 200.9029,
#   'train_samples_per_second': 3.818,
#   'train_steps_per_second': 0.478},
#  {'epoch': 16.0,
#   'grad_norm': 31.38544273376465,
#   'learning_rate': 9.333333333333334e-05,
#   'loss': 4.8073,
#   'step': 384},
#  {'epoch': 16.0,
#   'eval_accuracy': 0.3541666666666667,
#   'eval_f1': 0.2965578231292517,
#   'eval_loss': 5.31422758102417,
#   'eval_precision': 0.4328087167070218,
#   'eval_recall': 0.3825396825396825,
#   'eval_runtime': 33.3379,
#   'eval_samples_per_second': 2.88,
#   'eval_steps_per_second': 0.36,
#   'step': 384},
#  {'epoch': 17.0,
#   'step': 408,
#   'train_accuracy': 0.3767926988265971,
#   'train_f1': 0.31810845739530874,
#   'train_loss': 3.884141206741333,
#   'train_precision': 0.6251989664253178,
#   'train_recall': 0.38635886343730463,
#   'train_runtime': 199.997,
#   'train_samples_per_second': 3.835,
#   'train_steps_per_second': 0.48},
#  {'epoch': 17.0,
#   'grad_norm': 28.325868606567383,
#   'learning_rate': 9.222222222222223e-05,
#   'loss': 3.8811,
#   'step': 408},
#  {'epoch': 17.0,
#   'eval_accuracy': 0.46875,
#   'eval_f1': 0.42985534043455925,
#   'eval_loss': 3.181621551513672,
#   'eval_precision': 0.6793205654354766,
#   'eval_recall': 0.49358178053830226,
#   'eval_runtime': 32.4671,
#   'eval_samples_per_second': 2.957,
#   'eval_steps_per_second': 0.37,
#   'step': 408},
#  {'epoch': 18.0,
#   'step': 432,
#   'train_accuracy': 0.4002607561929596,
#   'train_f1': 0.3380616887350226,
#   'train_loss': 2.5352485179901123,
#   'train_precision': 0.5850641973249641,
#   'train_recall': 0.4142910373529195,
#   'train_runtime': 199.286,
#   'train_samples_per_second': 3.849,
#   'train_steps_per_second': 0.482},
#  {'epoch': 18.0,
#   'grad_norm': 20.700511932373047,
#   'learning_rate': 9.111111111111112e-05,
#   'loss': 2.9512,
#   'step': 432},
#  {'epoch': 18.0,
#   'eval_accuracy': 0.5,
#   'eval_f1': 0.429729792256108,
#   'eval_loss': 1.612800121307373,
#   'eval_precision': 0.728533231474408,
#   'eval_recall': 0.5020013802622498,
#   'eval_runtime': 32.2099,
#   'eval_samples_per_second': 2.98,
#   'eval_steps_per_second': 0.373,
#   'step': 432},
#  {'epoch': 19.0,
#   'step': 456,
#   'train_accuracy': 0.5384615384615384,
#   'train_f1': 0.5176704956664613,
#   'train_loss': 1.7885210514068604,
#   'train_precision': 0.6560987343841631,
#   'train_recall': 0.5439577465196359,
#   'train_runtime': 212.9426,
#   'train_samples_per_second': 3.602,
#   'train_steps_per_second': 0.451},
#  {'epoch': 19.0,
#   'grad_norm': 20.563547134399414,
#   'learning_rate': 9e-05,
#   'loss': 2.0072,
#   'step': 456},
#  {'epoch': 19.0,
#   'eval_accuracy': 0.5833333333333334,
#   'eval_f1': 0.5736154454712249,
#   'eval_loss': 1.1499067544937134,
#   'eval_precision': 0.7176190476190476,
#   'eval_recall': 0.5895013802622497,
#   'eval_runtime': 52.0506,
#   'eval_samples_per_second': 1.844,
#   'eval_steps_per_second': 0.231,
#   'step': 456},
#  {'epoch': 20.0,
#   'step': 480,
#   'train_accuracy': 0.5932203389830508,
#   'train_f1': 0.5828841458879652,
#   'train_loss': 1.414119005203247,
#   'train_precision': 0.6374258121174424,
#   'train_recall': 0.6095813523308241,
#   'train_runtime': 206.4886,
#   'train_samples_per_second': 3.714,
#   'train_steps_per_second': 0.465},
#  {'epoch': 20.0,
#   'grad_norm': 29.89242935180664,
#   'learning_rate': 8.888888888888889e-05,
#   'loss': 1.7121,
#   'step': 480},
#  {'epoch': 20.0,
#   'eval_accuracy': 0.6041666666666666,
#   'eval_f1': 0.5836819346909585,
#   'eval_loss': 1.095512866973877,
#   'eval_precision': 0.6815887544949331,
#   'eval_recall': 0.6141304347826086,
#   'eval_runtime': 32.9254,
#   'eval_samples_per_second': 2.916,
#   'eval_steps_per_second': 0.364,
#   'step': 480},
#  {'epoch': 21.0,
#   'step': 504,
#   'train_accuracy': 0.6714471968709257,
#   'train_f1': 0.6693322562605856,
#   'train_loss': 1.2010351419448853,
#   'train_precision': 0.7411999084251777,
#   'train_recall': 0.6742751854005691,
#   'train_runtime': 201.1032,
#   'train_samples_per_second': 3.814,
#   'train_steps_per_second': 0.477},
#  {'epoch': 21.0,
#   'grad_norm': 16.116666793823242,
#   'learning_rate': 8.777777777777778e-05,
#   'loss': 1.4847,
#   'step': 504},
#  {'epoch': 21.0,
#   'eval_accuracy': 0.6979166666666666,
#   'eval_f1': 0.6986793112229217,
#   'eval_loss': 0.9522600769996643,
#   'eval_precision': 0.7812739054844318,
#   'eval_recall': 0.6966701173222912,
#   'eval_runtime': 32.1641,
#   'eval_samples_per_second': 2.985,
#   'eval_steps_per_second': 0.373,
#   'step': 504},
#  {'epoch': 22.0,
#   'step': 528,
#   'train_accuracy': 0.7066492829204694,
#   'train_f1': 0.7103978917413256,
#   'train_loss': 1.045145034790039,
#   'train_precision': 0.7442845098583085,
#   'train_recall': 0.7120532713115729,
#   'train_runtime': 201.5407,
#   'train_samples_per_second': 3.806,
#   'train_steps_per_second': 0.476},
#  {'epoch': 22.0,
#   'grad_norm': 9.176497459411621,
#   'learning_rate': 8.666666666666667e-05,
#   'loss': 1.4197,
#   'step': 528},
#  {'epoch': 22.0,
#   'eval_accuracy': 0.7291666666666666,
#   'eval_f1': 0.7130128361765993,
#   'eval_loss': 0.9668137431144714,
#   'eval_precision': 0.7587382779198636,
#   'eval_recall': 0.7245427881297447,
#   'eval_runtime': 31.8759,
#   'eval_samples_per_second': 3.012,
#   'eval_steps_per_second': 0.376,
#   'step': 528},
#  {'epoch': 23.0,
#   'step': 552,
#   'train_accuracy': 0.7027379400260756,
#   'train_f1': 0.7042845941220757,
#   'train_loss': 1.0129259824752808,
#   'train_precision': 0.768643414286859,
#   'train_recall': 0.7048844715891098,
#   'train_runtime': 199.7352,
#   'train_samples_per_second': 3.84,
#   'train_steps_per_second': 0.481},
#  {'epoch': 23.0,
#   'grad_norm': 29.387168884277344,
#   'learning_rate': 8.555555555555556e-05,
#   'loss': 1.2351,
#   'step': 552},
#  {'epoch': 23.0,
#   'eval_accuracy': 0.7604166666666666,
#   'eval_f1': 0.755291640680635,
#   'eval_loss': 0.9272818565368652,
#   'eval_precision': 0.8193650793650793,
#   'eval_recall': 0.7506987577639751,
#   'eval_runtime': 31.8897,
#   'eval_samples_per_second': 3.01,
#   'eval_steps_per_second': 0.376,
#   'step': 552},
#  {'epoch': 24.0,
#   'step': 576,
#   'train_accuracy': 0.7027379400260756,
#   'train_f1': 0.7069158633210781,
#   'train_loss': 1.0423188209533691,
#   'train_precision': 0.7185841268636366,
#   'train_recall': 0.7141272855416341,
#   'train_runtime': 198.696,
#   'train_samples_per_second': 3.86,
#   'train_steps_per_second': 0.483},
#  {'epoch': 24.0,
#   'grad_norm': 10.762166976928711,
#   'learning_rate': 8.444444444444444e-05,
#   'loss': 1.2165,
#   'step': 576},
#  {'epoch': 24.0,
#   'eval_accuracy': 0.84375,
#   'eval_f1': 0.8320073071136902,
#   'eval_loss': 0.6986307501792908,
#   'eval_precision': 0.8643493761140821,
#   'eval_recall': 0.8382936507936508,
#   'eval_runtime': 32.0077,
#   'eval_samples_per_second': 2.999,
#   'eval_steps_per_second': 0.375,
#   'step': 576},
#  {'epoch': 25.0,
#   'step': 600,
#   'train_accuracy': 0.7444589308996089,
#   'train_f1': 0.7455927227143704,
#   'train_loss': 0.8882259130477905,
#   'train_precision': 0.7735089491409541,
#   'train_recall': 0.7525589025209922,
#   'train_runtime': 198.8178,
#   'train_samples_per_second': 3.858,
#   'train_steps_per_second': 0.483},
#  {'epoch': 25.0,
#   'grad_norm': 10.581185340881348,
#   'learning_rate': 8.333333333333334e-05,
#   'loss': 1.0305,
#   'step': 600},
#  {'epoch': 25.0,
#   'eval_accuracy': 0.8541666666666666,
#   'eval_f1': 0.8529806856726376,
#   'eval_loss': 0.6523558497428894,
#   'eval_precision': 0.8729031411895862,
#   'eval_recall': 0.8502329192546585,
#   'eval_runtime': 43.2831,
#   'eval_samples_per_second': 2.218,
#   'eval_steps_per_second': 0.277,
#   'step': 600},
#  {'epoch': 26.0,
#   'step': 624,
#   'train_accuracy': 0.7601043024771839,
#   'train_f1': 0.7611238002013508,
#   'train_loss': 0.7997403144836426,
#   'train_precision': 0.7852357087744433,
#   'train_recall': 0.7707002241838307,
#   'train_runtime': 198.6497,
#   'train_samples_per_second': 3.861,
#   'train_steps_per_second': 0.483},
#  {'epoch': 26.0,
#   'grad_norm': 7.4524054527282715,
#   'learning_rate': 8.222222222222222e-05,
#   'loss': 0.9823,
#   'step': 624},
#  {'epoch': 26.0,
#   'eval_accuracy': 0.8541666666666666,
#   'eval_f1': 0.8546006144393241,
#   'eval_loss': 0.6026266813278198,
#   'eval_precision': 0.8784193061840121,
#   'eval_recall': 0.8464285714285715,
#   'eval_runtime': 32.0285,
#   'eval_samples_per_second': 2.997,
#   'eval_steps_per_second': 0.375,
#   'step': 624},
#  {'epoch': 27.0,
#   'step': 648,
#   'train_accuracy': 0.8018252933507171,
#   'train_f1': 0.8075189281687936,
#   'train_loss': 0.7772456407546997,
#   'train_precision': 0.8083210103068266,
#   'train_recall': 0.814111336226105,
#   'train_runtime': 197.3514,
#   'train_samples_per_second': 3.886,
#   'train_steps_per_second': 0.486},
#  {'epoch': 27.0,
#   'grad_norm': 4.816295623779297,
#   'learning_rate': 8.111111111111112e-05,
#   'loss': 0.8345,
#   'step': 648},
#  {'epoch': 27.0,
#   'eval_accuracy': 0.84375,
#   'eval_f1': 0.8405016781487369,
#   'eval_loss': 0.6243665814399719,
#   'eval_precision': 0.8616402116402118,
#   'eval_recall': 0.8402777777777777,
#   'eval_runtime': 31.918,
#   'eval_samples_per_second': 3.008,
#   'eval_steps_per_second': 0.376,
#   'step': 648},
#  {'epoch': 28.0,
#   'step': 672,
#   'train_accuracy': 0.7940026075619296,
#   'train_f1': 0.7954094407414727,
#   'train_loss': 0.7567700743675232,
#   'train_precision': 0.8010135009903554,
#   'train_recall': 0.8099883131154526,
#   'train_runtime': 197.2651,
#   'train_samples_per_second': 3.888,
#   'train_steps_per_second': 0.487},
#  {'epoch': 28.0,
#   'grad_norm': 5.419092178344727,
#   'learning_rate': 8e-05,
#   'loss': 0.84,
#   'step': 672},
#  {'epoch': 28.0,
#   'eval_accuracy': 0.90625,
#   'eval_f1': 0.9024500486893979,
#   'eval_loss': 0.4989219903945923,
#   'eval_precision': 0.9138024408848209,
#   'eval_recall': 0.9067460317460319,
#   'eval_runtime': 31.7208,
#   'eval_samples_per_second': 3.026,
#   'eval_steps_per_second': 0.378,
#   'step': 672},
#  {'epoch': 29.0,
#   'step': 696,
#   'train_accuracy': 0.8357235984354628,
#   'train_f1': 0.8410030431047751,
#   'train_loss': 0.6362563371658325,
#   'train_precision': 0.8382865151198194,
#   'train_recall': 0.8473852481351727,
#   'train_runtime': 198.4152,
#   'train_samples_per_second': 3.866,
#   'train_steps_per_second': 0.484},
#  {'epoch': 29.0,
#   'grad_norm': 3.3163676261901855,
#   'learning_rate': 7.88888888888889e-05,
#   'loss': 0.7944,
#   'step': 696},
#  {'epoch': 29.0,
#   'eval_accuracy': 0.875,
#   'eval_f1': 0.8716790523242135,
#   'eval_loss': 0.4793645441532135,
#   'eval_precision': 0.881111111111111,
#   'eval_recall': 0.875,
#   'eval_runtime': 32.1908,
#   'eval_samples_per_second': 2.982,
#   'eval_steps_per_second': 0.373,
#   'step': 696},
#  {'epoch': 30.0,
#   'step': 720,
#   'train_accuracy': 0.8318122555410691,
#   'train_f1': 0.8375185666468976,
#   'train_loss': 0.6014121174812317,
#   'train_precision': 0.8367012732247753,
#   'train_recall': 0.8414952469152229,
#   'train_runtime': 200.9615,
#   'train_samples_per_second': 3.817,
#   'train_steps_per_second': 0.478},
#  {'epoch': 30.0,
#   'grad_norm': 5.528090000152588,
#   'learning_rate': 7.777777777777778e-05,
#   'loss': 0.8084,
#   'step': 720},
#  {'epoch': 30.0,
#   'eval_accuracy': 0.8854166666666666,
#   'eval_f1': 0.881111111111111,
#   'eval_loss': 0.49423882365226746,
#   'eval_precision': 0.8864585706690971,
#   'eval_recall': 0.881547619047619,
#   'eval_runtime': 31.9736,
#   'eval_samples_per_second': 3.002,
#   'eval_steps_per_second': 0.375,
#   'step': 720},
#  {'epoch': 31.0,
#   'step': 744,
#   'train_accuracy': 0.8135593220338984,
#   'train_f1': 0.8154274159562016,
#   'train_loss': 0.5738436579704285,
#   'train_precision': 0.8137732879027958,
#   'train_recall': 0.8285437735413629,
#   'train_runtime': 199.8621,
#   'train_samples_per_second': 3.838,
#   'train_steps_per_second': 0.48},
#  {'epoch': 31.0,
#   'grad_norm': 3.445253610610962,
#   'learning_rate': 7.666666666666667e-05,
#   'loss': 0.7024,
#   'step': 744},
#  {'epoch': 31.0,
#   'eval_accuracy': 0.9166666666666666,
#   'eval_f1': 0.915753223512137,
#   'eval_loss': 0.38265275955200195,
#   'eval_precision': 0.9217281170841541,
#   'eval_recall': 0.9176587301587302,
#   'eval_runtime': 31.8714,
#   'eval_samples_per_second': 3.012,
#   'eval_steps_per_second': 0.377,
#   'step': 744},
#  {'epoch': 32.0,
#   'step': 768,
#   'train_accuracy': 0.8604954367666232,
#   'train_f1': 0.8636798382420718,
#   'train_loss': 0.5211495757102966,
#   'train_precision': 0.8624850963704409,
#   'train_recall': 0.8696757126654365,
#   'train_runtime': 197.6223,
#   'train_samples_per_second': 3.881,
#   'train_steps_per_second': 0.486},
#  {'epoch': 32.0,
#   'grad_norm': 12.190242767333984,
#   'learning_rate': 7.555555555555556e-05,
#   'loss': 0.6897,
#   'step': 768},
#  {'epoch': 32.0,
#   'eval_accuracy': 0.9166666666666666,
#   'eval_f1': 0.9140620782726046,
#   'eval_loss': 0.40091660618782043,
#   'eval_precision': 0.9215686274509803,
#   'eval_recall': 0.9162698412698413,
#   'eval_runtime': 32.6244,
#   'eval_samples_per_second': 2.943,
#   'eval_steps_per_second': 0.368,
#   'step': 768},
#  {'epoch': 33.0,
#   'step': 792,
#   'train_accuracy': 0.8526727509778357,
#   'train_f1': 0.8568463427851686,
#   'train_loss': 0.46949502825737,
#   'train_precision': 0.8567073764232649,
#   'train_recall': 0.8634044771899306,
#   'train_runtime': 208.0531,
#   'train_samples_per_second': 3.687,
#   'train_steps_per_second': 0.461},
#  {'epoch': 33.0,
#   'grad_norm': 24.23414421081543,
#   'learning_rate': 7.444444444444444e-05,
#   'loss': 0.6695,
#   'step': 792},
#  {'epoch': 33.0,
#   'eval_accuracy': 0.90625,
#   'eval_f1': 0.9034442134442134,
#   'eval_loss': 0.3624160587787628,
#   'eval_precision': 0.9134740259740258,
#   'eval_recall': 0.9067460317460319,
#   'eval_runtime': 32.0237,
#   'eval_samples_per_second': 2.998,
#   'eval_steps_per_second': 0.375,
#   'step': 792},
#  {'epoch': 34.0,
#   'step': 816,
#   'train_accuracy': 0.8565840938722294,
#   'train_f1': 0.8607551398386482,
#   'train_loss': 0.46939951181411743,
#   'train_precision': 0.8572270762725294,
#   'train_recall': 0.8677456299976487,
#   'train_runtime': 200.1711,
#   'train_samples_per_second': 3.832,
#   'train_steps_per_second': 0.48},
#  {'epoch': 34.0,
#   'grad_norm': 3.1217308044433594,
#   'learning_rate': 7.333333333333333e-05,
#   'loss': 0.6694,
#   'step': 816},
#  {'epoch': 34.0,
#   'eval_accuracy': 0.9166666666666666,
#   'eval_f1': 0.9140620782726046,
#   'eval_loss': 0.2844057083129883,
#   'eval_precision': 0.9215686274509803,
#   'eval_recall': 0.9162698412698413,
#   'eval_runtime': 32.1314,
#   'eval_samples_per_second': 2.988,
#   'eval_steps_per_second': 0.373,
#   'step': 816},
#  {'epoch': 35.0,
#   'step': 840,
#   'train_accuracy': 0.8500651890482399,
#   'train_f1': 0.8563867009693327,
#   'train_loss': 0.4563950300216675,
#   'train_precision': 0.8569466828407526,
#   'train_recall': 0.8621128885632334,
#   'train_runtime': 196.2491,
#   'train_samples_per_second': 3.908,
#   'train_steps_per_second': 0.489},
#  {'epoch': 35.0,
#   'grad_norm': 10.602845191955566,
#   'learning_rate': 7.222222222222222e-05,
#   'loss': 0.6106,
#   'step': 840},
#  {'epoch': 35.0,
#   'eval_accuracy': 0.8854166666666666,
#   'eval_f1': 0.8821915751946712,
#   'eval_loss': 0.32399091124534607,
#   'eval_precision': 0.9084615384615384,
#   'eval_recall': 0.8876984126984127,
#   'eval_runtime': 45.2438,
#   'eval_samples_per_second': 2.122,
#   'eval_steps_per_second': 0.265,
#   'step': 840},
#  {'epoch': 36.0,
#   'step': 864,
#   'train_accuracy': 0.8591916558018253,
#   'train_f1': 0.8661246278634307,
#   'train_loss': 0.40078821778297424,
#   'train_precision': 0.8674530952091958,
#   'train_recall': 0.8680402440553567,
#   'train_runtime': 200.7363,
#   'train_samples_per_second': 3.821,
#   'train_steps_per_second': 0.478},
#  {'epoch': 36.0,
#   'grad_norm': 9.400073051452637,
#   'learning_rate': 7.111111111111112e-05,
#   'loss': 0.6414,
#   'step': 864},
#  {'epoch': 36.0,
#   'eval_accuracy': 0.8854166666666666,
#   'eval_f1': 0.8871455214918459,
#   'eval_loss': 0.2835704982280731,
#   'eval_precision': 0.904137254901961,
#   'eval_recall': 0.8859126984126984,
#   'eval_runtime': 32.2144,
#   'eval_samples_per_second': 2.98,
#   'eval_steps_per_second': 0.373,
#   'step': 864},
#  {'epoch': 37.0,
#   'step': 888,
#   'train_accuracy': 0.8683181225554107,
#   'train_f1': 0.8731320211854416,
#   'train_loss': 0.44349023699760437,
#   'train_precision': 0.8704982160938085,
#   'train_recall': 0.8775309872865394,
#   'train_runtime': 200.2034,
#   'train_samples_per_second': 3.831,
#   'train_steps_per_second': 0.48},
#  {'epoch': 37.0,
#   'grad_norm': 4.9167914390563965,
#   'learning_rate': 7e-05,
#   'loss': 0.6352,
#   'step': 888},
#  {'epoch': 37.0,
#   'eval_accuracy': 0.9375,
#   'eval_f1': 0.9347636725300397,
#   'eval_loss': 0.25888702273368835,
#   'eval_precision': 0.9389473684210525,
#   'eval_recall': 0.9337301587301587,
#   'eval_runtime': 31.7984,
#   'eval_samples_per_second': 3.019,
#   'eval_steps_per_second': 0.377,
#   'step': 888},
#  {'epoch': 38.0,
#   'step': 912,
#   'train_accuracy': 0.8748370273794003,
#   'train_f1': 0.8787678939672805,
#   'train_loss': 0.40917009115219116,
#   'train_precision': 0.878090804119578,
#   'train_recall': 0.881849204695403,
#   'train_runtime': 200.9698,
#   'train_samples_per_second': 3.816,
#   'train_steps_per_second': 0.478},
#  {'epoch': 38.0,
#   'grad_norm': 2.153257131576538,
#   'learning_rate': 6.88888888888889e-05,
#   'loss': 0.5227,
#   'step': 912},
#  {'epoch': 38.0,
#   'eval_accuracy': 0.9583333333333334,
#   'eval_f1': 0.9589473684210527,
#   'eval_loss': 0.20821267366409302,
#   'eval_precision': 0.9594736842105263,
#   'eval_recall': 0.9603174603174602,
#   'eval_runtime': 31.8024,
#   'eval_samples_per_second': 3.019,
#   'eval_steps_per_second': 0.377,
#   'step': 912},
#  {'epoch': 39.0,
#   'step': 936,
#   'train_accuracy': 0.9061277705345502,
#   'train_f1': 0.9098301366009611,
#   'train_loss': 0.34501832723617554,
#   'train_precision': 0.9103150207572867,
#   'train_recall': 0.9161307271963011,
#   'train_runtime': 199.5917,
#   'train_samples_per_second': 3.843,
#   'train_steps_per_second': 0.481},
#  {'epoch': 39.0,
#   'grad_norm': 17.838909149169922,
#   'learning_rate': 6.777777777777778e-05,
#   'loss': 0.5822,
#   'step': 936},
#  {'epoch': 39.0,
#   'eval_accuracy': 0.9270833333333334,
#   'eval_f1': 0.9252984940715281,
#   'eval_loss': 0.20341236889362335,
#   'eval_precision': 0.9365217391304348,
#   'eval_recall': 0.9303571428571429,
#   'eval_runtime': 36.5334,
#   'eval_samples_per_second': 2.628,
#   'eval_steps_per_second': 0.328,
#   'step': 936},
#  {'epoch': 40.0,
#   'step': 960,
#   'train_accuracy': 0.9139504563233377,
#   'train_f1': 0.9182222309677842,
#   'train_loss': 0.3196386396884918,
#   'train_precision': 0.9178474828518013,
#   'train_recall': 0.9194311934573957,
#   'train_runtime': 201.3318,
#   'train_samples_per_second': 3.81,
#   'train_steps_per_second': 0.477},
#  {'epoch': 40.0,
#   'grad_norm': 6.985750198364258,
#   'learning_rate': 6.666666666666667e-05,
#   'loss': 0.5097,
#   'step': 960},
#  {'epoch': 40.0,
#   'eval_accuracy': 0.9479166666666666,
#   'eval_f1': 0.9486446886446886,
#   'eval_loss': 0.20123909413814545,
#   'eval_precision': 0.9513784461152882,
#   'eval_recall': 0.9492063492063492,
#   'eval_runtime': 32.4384,
#   'eval_samples_per_second': 2.959,
#   'eval_steps_per_second': 0.37,
#   'step': 960},
#  {'epoch': 41.0,
#   'step': 984,
#   'train_accuracy': 0.9009126466753585,
#   'train_f1': 0.9056630769120806,
#   'train_loss': 0.3056108355522156,
#   'train_precision': 0.9051454353540891,
#   'train_recall': 0.9067893664497749,
#   'train_runtime': 200.9605,
#   'train_samples_per_second': 3.817,
#   'train_steps_per_second': 0.478},
#  {'epoch': 41.0,
#   'grad_norm': 8.800042152404785,
#   'learning_rate': 6.555555555555556e-05,
#   'loss': 0.5101,
#   'step': 984},
#  {'epoch': 41.0,
#   'eval_accuracy': 0.9375,
#   'eval_f1': 0.9371940053224597,
#   'eval_loss': 0.17687702178955078,
#   'eval_precision': 0.9400292397660819,
#   'eval_recall': 0.9382936507936508,
#   'eval_runtime': 31.7947,
#   'eval_samples_per_second': 3.019,
#   'eval_steps_per_second': 0.377,
#   'step': 984},
#  {'epoch': 42.0,
#   'step': 1008,
#   'train_accuracy': 0.9074315514993481,
#   'train_f1': 0.910891215042575,
#   'train_loss': 0.31013280153274536,
#   'train_precision': 0.9107309406044181,
#   'train_recall': 0.9127010423805716,
#   'train_runtime': 197.925,
#   'train_samples_per_second': 3.875,
#   'train_steps_per_second': 0.485},
#  {'epoch': 42.0,
#   'grad_norm': 6.042183876037598,
#   'learning_rate': 6.444444444444446e-05,
#   'loss': 0.4837,
#   'step': 1008},
#  {'epoch': 42.0,
#   'eval_accuracy': 0.9583333333333334,
#   'eval_f1': 0.9589473684210527,
#   'eval_loss': 0.156900092959404,
#   'eval_precision': 0.9594736842105263,
#   'eval_recall': 0.9603174603174602,
#   'eval_runtime': 31.708,
#   'eval_samples_per_second': 3.028,
#   'eval_steps_per_second': 0.378,
#   'step': 1008},
#  {'epoch': 43.0,
#   'step': 1032,
#   'train_accuracy': 0.9230769230769231,
#   'train_f1': 0.9267857213358305,
#   'train_loss': 0.3038622736930847,
#   'train_precision': 0.9248190200929475,
#   'train_recall': 0.9295518158972081,
#   'train_runtime': 199.3613,
#   'train_samples_per_second': 3.847,
#   'train_steps_per_second': 0.482},
#  {'epoch': 43.0,
#   'grad_norm': 3.7202463150024414,
#   'learning_rate': 6.333333333333333e-05,
#   'loss': 0.5051,
#   'step': 1032},
#  {'epoch': 43.0,
#   'eval_accuracy': 0.9375,
#   'eval_f1': 0.9363284140873276,
#   'eval_loss': 0.16232264041900635,
#   'eval_precision': 0.9388888888888889,
#   'eval_recall': 0.9382936507936508,
#   'eval_runtime': 31.8818,
#   'eval_samples_per_second': 3.011,
#   'eval_steps_per_second': 0.376,
#   'step': 1032},
#  {'epoch': 44.0,
#   'step': 1056,
#   'train_accuracy': 0.9152542372881356,
#   'train_f1': 0.9184982706417697,
#   'train_loss': 0.3018590211868286,
#   'train_precision': 0.9169669778532622,
#   'train_recall': 0.9221986293466525,
#   'train_runtime': 222.5904,
#   'train_samples_per_second': 3.446,
#   'train_steps_per_second': 0.431},
#  {'epoch': 44.0,
#   'grad_norm': 4.302759647369385,
#   'learning_rate': 6.222222222222222e-05,
#   'loss': 0.4597,
#   'step': 1056},
#  {'epoch': 44.0,
#   'eval_accuracy': 0.9479166666666666,
#   'eval_f1': 0.9474127260674962,
#   'eval_loss': 0.15101146697998047,
#   'eval_precision': 0.951984126984127,
#   'eval_recall': 0.9478174603174603,
#   'eval_runtime': 33.1209,
#   'eval_samples_per_second': 2.898,
#   'eval_steps_per_second': 0.362,
#   'step': 1056},
#  {'epoch': 45.0,
#   'step': 1080,
#   'train_accuracy': 0.9139504563233377,
#   'train_f1': 0.9174995311868465,
#   'train_loss': 0.2525468170642853,
#   'train_precision': 0.9180371365981144,
#   'train_recall': 0.9184429076476748,
#   'train_runtime': 202.671,
#   'train_samples_per_second': 3.784,
#   'train_steps_per_second': 0.474},
#  {'epoch': 45.0,
#   'grad_norm': 4.127688407897949,
#   'learning_rate': 6.111111111111112e-05,
#   'loss': 0.484,
#   'step': 1080},
#  {'epoch': 45.0,
#   'eval_accuracy': 0.96875,
#   'eval_f1': 0.9691496374423203,
#   'eval_loss': 0.12108068913221359,
#   'eval_precision': 0.9689473684210526,
#   'eval_recall': 0.9698412698412697,
#   'eval_runtime': 32.9551,
#   'eval_samples_per_second': 2.913,
#   'eval_steps_per_second': 0.364,
#   'step': 1080},
#  {'epoch': 46.0,
#   'step': 1104,
#   'train_accuracy': 0.9217731421121251,
#   'train_f1': 0.9254762297173749,
#   'train_loss': 0.27687788009643555,
#   'train_precision': 0.9267979379214607,
#   'train_recall': 0.9253534566507986,
#   'train_runtime': 198.3624,
#   'train_samples_per_second': 3.867,
#   'train_steps_per_second': 0.484},
#  {'epoch': 46.0,
#   'grad_norm': 11.13309383392334,
#   'learning_rate': 6e-05,
#   'loss': 0.4049,
#   'step': 1104},
#  {'epoch': 46.0,
#   'eval_accuracy': 0.9583333333333334,
#   'eval_f1': 0.9572926191336892,
#   'eval_loss': 0.12955482304096222,
#   'eval_precision': 0.958421052631579,
#   'eval_recall': 0.9573412698412698,
#   'eval_runtime': 31.3977,
#   'eval_samples_per_second': 3.058,
#   'eval_steps_per_second': 0.382,
#   'step': 1104},
#  {'epoch': 47.0,
#   'step': 1128,
#   'train_accuracy': 0.9178617992177314,
#   'train_f1': 0.921429348865685,
#   'train_loss': 0.24908125400543213,
#   'train_precision': 0.9198634568241868,
#   'train_recall': 0.9246967514484463,
#   'train_runtime': 199.8364,
#   'train_samples_per_second': 3.838,
#   'train_steps_per_second': 0.48},
#  {'epoch': 47.0,
#   'grad_norm': 9.567635536193848,
#   'learning_rate': 5.8888888888888896e-05,
#   'loss': 0.462,
#   'step': 1128},
#  {'epoch': 47.0,
#   'eval_accuracy': 0.9583333333333334,
#   'eval_f1': 0.9573737509221381,
#   'eval_loss': 0.13671334087848663,
#   'eval_precision': 0.9609022556390977,
#   'eval_recall': 0.9589285714285716,
#   'eval_runtime': 34.2945,
#   'eval_samples_per_second': 2.799,
#   'eval_steps_per_second': 0.35,
#   'step': 1128},
#  {'epoch': 48.0,
#   'step': 1152,
#   'train_accuracy': 0.9256844850065189,
#   'train_f1': 0.9296378464871029,
#   'train_loss': 0.26442447304725647,
#   'train_precision': 0.9290750432944004,
#   'train_recall': 0.9314548028170707,
#   'train_runtime': 198.7458,
#   'train_samples_per_second': 3.859,
#   'train_steps_per_second': 0.483},
#  {'epoch': 48.0,
#   'grad_norm': 4.712935447692871,
#   'learning_rate': 5.7777777777777776e-05,
#   'loss': 0.4554,
#   'step': 1152},
#  {'epoch': 48.0,
#   'eval_accuracy': 0.9583333333333334,
#   'eval_f1': 0.9589010989010989,
#   'eval_loss': 0.11816411465406418,
#   'eval_precision': 0.9636363636363636,
#   'eval_recall': 0.9603174603174602,
#   'eval_runtime': 31.5661,
#   'eval_samples_per_second': 3.041,
#   'eval_steps_per_second': 0.38,
#   'step': 1152},
#  {'epoch': 49.0,
#   'step': 1176,
#   'train_accuracy': 0.9322033898305084,
#   'train_f1': 0.9355838135934308,
#   'train_loss': 0.24854031205177307,
#   'train_precision': 0.9349248636194067,
#   'train_recall': 0.9372913093406552,
#   'train_runtime': 195.0873,
#   'train_samples_per_second': 3.932,
#   'train_steps_per_second': 0.492},
#  {'epoch': 49.0,
#   'grad_norm': 10.066852569580078,
#   'learning_rate': 5.666666666666667e-05,
#   'loss': 0.3727,
#   'step': 1176},
#  {'epoch': 49.0,
#   'eval_accuracy': 0.9479166666666666,
#   'eval_f1': 0.9462367113430943,
#   'eval_loss': 0.1487860530614853,
#   'eval_precision': 0.9525689223057645,
#   'eval_recall': 0.9464285714285715,
#   'eval_runtime': 31.3639,
#   'eval_samples_per_second': 3.061,
#   'eval_steps_per_second': 0.383,
#   'step': 1176},
#  {'epoch': 50.0,
#   'step': 1200,
#   'train_accuracy': 0.9282920469361148,
#   'train_f1': 0.9297281553178071,
#   'train_loss': 0.22614161670207977,
#   'train_precision': 0.9281473102061337,
#   'train_recall': 0.9326388766988302,
#   'train_runtime': 194.9107,
#   'train_samples_per_second': 3.935,
#   'train_steps_per_second': 0.493},
#  {'epoch': 50.0,
#   'grad_norm': 11.0418062210083,
#   'learning_rate': 5.555555555555556e-05,
#   'loss': 0.4282,
#   'step': 1200},
#  {'epoch': 50.0,
#   'eval_accuracy': 0.9791666666666666,
#   'eval_f1': 0.9794736842105263,
#   'eval_loss': 0.09479834884405136,
#   'eval_precision': 0.9800000000000001,
#   'eval_recall': 0.980952380952381,
#   'eval_runtime': 32.2186,
#   'eval_samples_per_second': 2.98,
#   'eval_steps_per_second': 0.372,
#   'step': 1200},
#  {'train_runtime': 0.1871,
#   'train_samples_per_second': 205003.853,
#   'train_steps_per_second': 6414.723,
#   'total_flos': 8.145906319789056e+17,
#   'train_loss': 0.0,
#   'epoch': 50.0,
#   'step': 1200},
#  {'eval_loss': 0.10966723412275314,
#   'eval_precision': 0.958119658119658,
#   'eval_recall': 0.9519047619047619,
#   'eval_f1': 0.9525641025641025,
#   'eval_accuracy': 0.9479166666666666,
#   'eval_runtime': 97.9714,
#   'eval_samples_per_second': 0.98,
#   'eval_steps_per_second': 0.122,
#   'epoch': 50.0,
#   'step': 1200}]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Extract relevant data
train_losses = []
eval_losses = []

eval_accuracy = []
train_accuracy = []

for item in history[:-1]: # exclude the log history of evaluation
    if 'loss' in item:
        train_losses.append(item['loss'])
    if 'eval_loss' in item:
        eval_losses.append(item['eval_loss'])
    if 'eval_accuracy' in item:
        eval_accuracy.append(item['eval_accuracy'])
    if 'train_accuracy' in item:
        train_accuracy.append(item['train_accuracy'])


# Plot
plt.figure(figsize=(10, 5))
epochs = range(1, len(train_losses) + 1)

# Plot training and  evaluation losses
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, eval_losses, label='Eval Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Evaluation Loss')
plt.legend()
plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

# Plot evaluation and training accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, eval_accuracy, label='Eval Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Evaluation Accuracies')
plt.legend()

plt.tight_layout()
plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.subplots_adjust(wspace=0.5)  # Adjust the width space between subplots
plt.savefig("train_and_eval.jpg", dpi=300)
plt.show()

# %% [markdown]
# # Inference
#
# Let's say you have a new image, on which you'd like to make a prediction. Let's load an image of tree bark, and see how the model does.

# %%
os.listdir()

# %%
from PIL import Image
import requests

img_path = r"example_tree.jpg"
image = Image.open(img_path)
image.resize(crop_size)

# %%
from transformers import AutoModelForImageClassification, AutoImageProcessor

repo_name = f"{model_name}-finetuned-FBark"

image_processor = AutoImageProcessor.from_pretrained(repo_name)
model = AutoModelForImageClassification.from_pretrained(repo_name)

# %%
# prepare image for the model
encoding = image_processor(image.convert("RGB"), return_tensors="pt")
print(encoding.pixel_values.shape)

# %%
import torch

# forward pass
with torch.no_grad():
    outputs = model(**encoding)
    logits = outputs.logits

# %%
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])

# %% [markdown]
# ## Pipeline API
#
# An alternative way to quickly perform inference with any model on the hub is by leveraging the [Pipeline API](https://huggingface.co/docs/transformers/main_classes/pipelines), which abstracts away all the steps we did manually above for us. It will perform the preprocessing, forward pass and postprocessing all in a single object.
#
# Let's showcase this for our trained model:

# %%
from transformers import pipeline

pipe = pipeline("image-classification", repo_name)

# %%
pipe(image)

# %% [markdown]
# As we can see, it does not only show the class label with the highest probability, but does return the top 5 labels, with their corresponding scores. Note that the pipelines also work with local models and mage processors:

# %%
pipe = pipeline("image-classification",
                model=model,
                feature_extractor=image_processor)

# %%
pipe(image)
